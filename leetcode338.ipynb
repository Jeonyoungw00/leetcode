# %% [markdown]
# #####**[LeetCode 338](https://leetcode.com/problems/counting-bits/)**

# %%
class Solution:
    def countBits(self, n: int) -> List[int]:
        l=[]
        for i in range(n+1):
            a=str(bin(i)[2:])
            l.append(a.count('1'))
        return l
