# %% [markdown]
# #####**[LeetCode 693](https://leetcode.com/problems/binary-number-with-alternating-bits/description/)**

# %%
class Solution:
    def hasAlternatingBits(self, n: int) -> bool:
        d = bin(n)[2:]
        s = str(d)
        u = s[::2]
        g = s[1::2]
        if(n==1 or n==0):
            return True
        if(set(u)== {'0'} and set(g)=={'1'}) or (set(u)== {'1'} and set(g)=={'0'}) :
            return True
        else:
            return False
