# %% [markdown]
# #####**[LeetCode 231](https://leetcode.com/problems/power-of-two/description/)**

# %%
class Solution:
    def isPowerOfTwo(self, n: int) -> bool:
        for i in range(31):
            ans = 2 ** i
            if ans == n:
                return True
        return False
