# %% [markdown]
# #####**[LeetCode 168](https://leetcode.com/problems/excel-sheet-column-title/solutions/3943071/100-recursive-iterative-2-approaches/)**

# %%
class Solution:
    def convertToTitle(self, columnNumber: int) -> str:
        result = []
        while columnNumber:
            columnNumber, remainder = divmod(columnNumber - 1, 26)
            result.append(chr(65 + remainder))
        return ''.join(reversed(result))
